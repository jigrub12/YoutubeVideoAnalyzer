# %%
import cv2
import os

# Directory where the video files are stored
video_dir = 'YouTubeClips/YouTubeClips'

# Base directory where you want to save the frames
output_base_dir = 'frames'
os.makedirs(output_base_dir, exist_ok=True)

# Log file to keep track of processed files
log_file = 'processed_files.log'
count_file = 'processed_count.log'

# Read the list of already processed files
if os.path.exists(log_file):
    with open(log_file, 'r') as f:
        processed_files = f.read().splitlines()
else:
    processed_files = []

# Read the count of already processed files
if os.path.exists(count_file):
    with open(count_file, 'r') as f:
        processed_count = int(f.read().strip())
else:
    processed_count = 0

# List all AVI files in the video directory and sort them alphabetically
all_video_files = sorted([f for f in os.listdir(video_dir) if f.endswith('.avi')])

# Filter out the already processed files
new_video_files = [f for f in all_video_files if f not in processed_files]

# Process the next 50 new AVI files
for video_index, video_file in enumerate(new_video_files[:50], start=processed_count + 1):
    video_path = os.path.join(video_dir, video_file)
    
    # Create a directory for the current video's frames named as `51`, `52`, etc.
    video_output_dir = os.path.join(output_base_dir, str(video_index))
    os.makedirs(video_output_dir, exist_ok=True)

    # Open the video
    cap = cv2.VideoCapture(video_path)

    # Check if the video was opened successfully
    if not cap.isOpened():
        print(f"Error: Could not open video {video_file}.")
        continue

    # Get the frame rate of the video
    fps = cap.get(cv2.CAP_PROP_FPS)
    skip_frames = int(fps * 2)  # Change it to modulate the number of frames
    
    # Frame count initialization
    frame_count = 0
    saved_frame_count = 0

    # Read frames from the video
    while True:
        ret, frame = cap.read()

        # Check if frame is read correctly
        if not ret:
            print(f"Reached end of video or failed to read frame from {video_file}.")
            break

        # Save a frame every second based on the video's frame rate
        if frame_count % int(skip_frames) == 0:
            # Naming convention: <video_index>_<frame_index>.jpg
            frame_filename = os.path.join(video_output_dir, f"{video_index}_{saved_frame_count}.jpg")
            cv2.imwrite(frame_filename, frame)
            print(f"Saved {frame_filename}")
            saved_frame_count += 1

        frame_count += 1

    # Release the video capture object
    cap.release()
    print(f"Total frames extracted from {video_file}: {saved_frame_count}")

    # Update the log file with the processed video file
    with open(log_file, 'a') as f:
        f.write(video_file + '\n')

# Update the count of processed files
processed_count += 50
with open(count_file, 'w') as f:
    f.write(str(processed_count))
# Out:
# Saved frames\151\151_0.jpg
# Saved frames\151\151_1.jpg
# Reached end of video or failed to read frame from 2YhDTpzxd3c_102_105.avi.
# Total frames extracted from 2YhDTpzxd3c_102_105.avi: 2
# Saved frames\152\152_0.jpg
# Saved frames\152\152_1.jpg
# Saved frames\152\152_2.jpg
# Reached end of video or failed to read frame from 2YhDTpzxd3c_115_120.avi.
# Total frames extracted from 2YhDTpzxd3c_115_120.avi: 3
# Saved frames\153\153_0.jpg
# Saved frames\153\153_1.jpg
# Saved frames\153\153_2.jpg
# Reached end of video or failed to read frame from 2YhDTpzxd3c_149_154.avi.
# Total frames extracted from 2YhDTpzxd3c_149_154.avi: 3
# Saved frames\154\154_0.jpg
# Saved frames\154\154_1.jpg
# Saved frames\154\154_2.jpg
# Reached end of video or failed to read frame from 2YhDTpzxd3c_166_170.avi.
# Total frames extracted from 2YhDTpzxd3c_166_170.avi: 3
# Saved frames\155\155_0.jpg
# Saved frames\155\155_1.jpg
# Saved frames\155\155_2.jpg
# Saved frames\155\155_3.jpg
# Reached end of video or failed to read frame from 2YhDTpzxd3c_174_180.avi.
# Total frames extracted from 2YhDTpzxd3c_174_180.avi: 4
# Saved frames\156\156_0.jpg
# Saved frames\156\156_1.jpg
# Saved frames\156\156_2.jpg
# Saved frames\156\156_3.jpg
# Saved frames\156\156_4.jpg
# Reached end of video or failed to read frame from 2YhDTpzxd3c_223_232.avi.
# Total frames extracted from 2YhDTpzxd3c_223_232.avi: 5
# Saved frames\157\157_0.jpg
# Saved frames\157\157_1.jpg
# Saved frames\157\157_2.jpg
# Reached end of video or failed to read frame from 2YhDTpzxd3c_22_27.avi.
# Total frames extracted from 2YhDTpzxd3c_22_27.avi: 3
# Saved frames\158\158_0.jpg
# Saved frames\158\158_1.jpg
# Saved frames\158\158_2.jpg
# Reached end of video or failed to read frame from 2YhDTpzxd3c_240_245.avi.
# Total frames extracted from 2YhDTpzxd3c_240_245.avi: 3
# Saved frames\159\159_0.jpg
# Saved frames\159\159_1.jpg
# Saved frames\159\159_2.jpg
# Reached end of video or failed to read frame from 2YhDTpzxd3c_45_49.avi.
# Total frames extracted from 2YhDTpzxd3c_45_49.avi: 3
# Saved frames\160\160_0.jpg
# Saved frames\160\160_1.jpg
# Reached end of video or failed to read frame from 2YhDTpzxd3c_98_101.avi.
# Total frames extracted from 2YhDTpzxd3c_98_101.avi: 2
# Saved frames\161\161_0.jpg
# Saved frames\161\161_1.jpg
# Saved frames\161\161_2.jpg
# Saved frames\161\161_3.jpg
# Saved frames\161\161_4.jpg
# Reached end of video or failed to read frame from 2jXxtQRy47A_30_38.avi.
# Total frames extracted from 2jXxtQRy47A_30_38.avi: 5
# Saved frames\162\162_0.jpg
# Saved frames\162\162_1.jpg
# Saved frames\162\162_2.jpg
# Saved frames\162\162_3.jpg
# Reached end of video or failed to read frame from 2jkExrrm_sQ_19_25.avi.
# Total frames extracted from 2jkExrrm_sQ_19_25.avi: 4
# Saved frames\163\163_0.jpg
# Saved frames\163\163_1.jpg
# Saved frames\163\163_2.jpg
# Saved frames\163\163_3.jpg
# Saved frames\163\163_4.jpg
# Reached end of video or failed to read frame from 2mUMTFnQWaw_1_9.avi.
# Total frames extracted from 2mUMTFnQWaw_1_9.avi: 5
# Saved frames\164\164_0.jpg
# Saved frames\164\164_1.jpg
# Saved frames\164\164_2.jpg
# Saved frames\164\164_3.jpg
# Saved frames\164\164_4.jpg
# Reached end of video or failed to read frame from 2xpIT0L4GqE_1_10.avi.
# Total frames extracted from 2xpIT0L4GqE_1_10.avi: 5
# Saved frames\165\165_0.jpg
# Saved frames\165\165_1.jpg
# Saved frames\165\165_2.jpg
# Reached end of video or failed to read frame from 30GeJHYoerk_121_126.avi.
# Total frames extracted from 30GeJHYoerk_121_126.avi: 3
# Saved frames\166\166_0.jpg
# Saved frames\166\166_1.jpg
# Saved frames\166\166_2.jpg
# Saved frames\166\166_3.jpg
# Saved frames\166\166_4.jpg
# Saved frames\166\166_5.jpg
# Saved frames\166\166_6.jpg
# Reached end of video or failed to read frame from 30GeJHYoerk_63_75.avi.
# Total frames extracted from 30GeJHYoerk_63_75.avi: 7
# Saved frames\167\167_0.jpg
# Saved frames\167\167_1.jpg
# Saved frames\167\167_2.jpg
# Reached end of video or failed to read frame from 30GeJHYoerk_80_85.avi.
# Total frames extracted from 30GeJHYoerk_80_85.avi: 3
# Saved frames\168\168_0.jpg
# Saved frames\168\168_1.jpg
# Saved frames\168\168_2.jpg
# Saved frames\168\168_3.jpg
# Saved frames\168\168_4.jpg
# Saved frames\168\168_5.jpg
# Saved frames\168\168_6.jpg
# Saved frames\168\168_7.jpg
# Reached end of video or failed to read frame from 30PpKtVT8Z4_35_50.avi.
# Total frames extracted from 30PpKtVT8Z4_35_50.avi: 8
# Saved frames\169\169_0.jpg
# Saved frames\169\169_1.jpg
# Saved frames\169\169_2.jpg
# Reached end of video or failed to read frame from 32_A0-er4Ws_16_20.avi.
# Total frames extracted from 32_A0-er4Ws_16_20.avi: 3
# Saved frames\170\170_0.jpg
# Saved frames\170\170_1.jpg
# Saved frames\170\170_2.jpg
# Saved frames\170\170_3.jpg
# Saved frames\170\170_4.jpg
# Reached end of video or failed to read frame from 39Ce7I6nXIw_96_104.avi.
# Total frames extracted from 39Ce7I6nXIw_96_104.avi: 5
# Saved frames\171\171_0.jpg
# Saved frames\171\171_1.jpg
# Saved frames\171\171_2.jpg
# Reached end of video or failed to read frame from 3FnUTQMJVXI_31_36.avi.
# Total frames extracted from 3FnUTQMJVXI_31_36.avi: 3
# Saved frames\172\172_0.jpg
# Saved frames\172\172_1.jpg
# Saved frames\172\172_2.jpg
# Reached end of video or failed to read frame from 3I9tSDU-OSk_17_22.avi.
# Total frames extracted from 3I9tSDU-OSk_17_22.avi: 3
# Saved frames\173\173_0.jpg
# Saved frames\173\173_1.jpg
# Saved frames\173\173_2.jpg
# Reached end of video or failed to read frame from 3OPQqH3YlHA_50_54.avi.
# Total frames extracted from 3OPQqH3YlHA_50_54.avi: 3
# Saved frames\174\174_0.jpg
# Saved frames\174\174_1.jpg
# Saved frames\174\174_2.jpg
# Saved frames\174\174_3.jpg
# Reached end of video or failed to read frame from 3SKyc0aKx70_46_52.avi.
# Total frames extracted from 3SKyc0aKx70_46_52.avi: 4
# Saved frames\175\175_0.jpg
# Saved frames\175\175_1.jpg
# Saved frames\175\175_2.jpg
# Saved frames\175\175_3.jpg
# Saved frames\175\175_4.jpg
# Reached end of video or failed to read frame from 3_51FhosiVY_93_101.avi.
# Total frames extracted from 3_51FhosiVY_93_101.avi: 5
# Saved frames\176\176_0.jpg
# Saved frames\176\176_1.jpg
# Saved frames\176\176_2.jpg
# Saved frames\176\176_3.jpg
# Saved frames\176\176_4.jpg
# Saved frames\176\176_5.jpg
# Reached end of video or failed to read frame from 3chNlP5TeO8_0_10.avi.
# Total frames extracted from 3chNlP5TeO8_0_10.avi: 6
# Saved frames\177\177_0.jpg
# Saved frames\177\177_1.jpg
# Saved frames\177\177_2.jpg
# Saved frames\177\177_3.jpg
# Saved frames\177\177_4.jpg
# Saved frames\177\177_5.jpg
# Reached end of video or failed to read frame from 3doK4FQM5-k_46_57.avi.
# Total frames extracted from 3doK4FQM5-k_46_57.avi: 6
# Saved frames\178\178_0.jpg
# Saved frames\178\178_1.jpg
# Saved frames\178\178_2.jpg
# Saved frames\178\178_3.jpg
# Saved frames\178\178_4.jpg
# Saved frames\178\178_5.jpg
# Saved frames\178\178_6.jpg
# Reached end of video or failed to read frame from 3eqFFRSXwGE_84_96.avi.
# Total frames extracted from 3eqFFRSXwGE_84_96.avi: 7
# Saved frames\179\179_0.jpg
# Saved frames\179\179_1.jpg
# Saved frames\179\179_2.jpg
# Saved frames\179\179_3.jpg
# Saved frames\179\179_4.jpg
# Saved frames\179\179_5.jpg
# Reached end of video or failed to read frame from 3ftaoFnhTyY_140_150.avi.
# Total frames extracted from 3ftaoFnhTyY_140_150.avi: 6
# Saved frames\180\180_0.jpg
# Saved frames\180\180_1.jpg
# Saved frames\180\180_2.jpg
# Saved frames\180\180_3.jpg
# Saved frames\180\180_4.jpg
# Saved frames\180\180_5.jpg
# Saved frames\180\180_6.jpg
# Saved frames\180\180_7.jpg
# Reached end of video or failed to read frame from 3lBHYoI5V8s_30_45.avi.
# Total frames extracted from 3lBHYoI5V8s_30_45.avi: 8
# Saved frames\181\181_0.jpg
# Saved frames\181\181_1.jpg
# Saved frames\181\181_2.jpg
# Saved frames\181\181_3.jpg
# Saved frames\181\181_4.jpg
# Reached end of video or failed to read frame from 3mbBbFH9fAg_21_29.avi.
# Total frames extracted from 3mbBbFH9fAg_21_29.avi: 5
# Saved frames\182\182_0.jpg
# Saved frames\182\182_1.jpg
# Saved frames\182\182_2.jpg
# Saved frames\182\182_3.jpg
# Saved frames\182\182_4.jpg
# Saved frames\182\182_5.jpg
# Saved frames\182\182_6.jpg
# Saved frames\182\182_7.jpg
# Saved frames\182\182_8.jpg
# Saved frames\182\182_9.jpg
# Saved frames\182\182_10.jpg
# Saved frames\182\182_11.jpg
# Reached end of video or failed to read frame from 3n_Kqak2JdA_48_71.avi.
# Total frames extracted from 3n_Kqak2JdA_48_71.avi: 12
# Saved frames\183\183_0.jpg
# Saved frames\183\183_1.jpg
# Saved frames\183\183_2.jpg
# Saved frames\183\183_3.jpg
# Saved frames\183\183_4.jpg
# Saved frames\183\183_5.jpg
# Saved frames\183\183_6.jpg
# Saved frames\183\183_7.jpg
# Saved frames\183\183_8.jpg
# Reached end of video or failed to read frame from 3opDcpPxllE_50_66.avi.
# Total frames extracted from 3opDcpPxllE_50_66.avi: 9
# Saved frames\184\184_0.jpg
# Saved frames\184\184_1.jpg
# Saved frames\184\184_2.jpg
# Saved frames\184\184_3.jpg
# Saved frames\184\184_4.jpg
# Saved frames\184\184_5.jpg
# Saved frames\184\184_6.jpg
# Saved frames\184\184_7.jpg
# Reached end of video or failed to read frame from 3qqEKTPxLNs_1_15.avi.
# Total frames extracted from 3qqEKTPxLNs_1_15.avi: 8
# Saved frames\185\185_0.jpg
# Saved frames\185\185_1.jpg
# Saved frames\185\185_2.jpg
# Saved frames\185\185_3.jpg
# Saved frames\185\185_4.jpg
# Saved frames\185\185_5.jpg
# Reached end of video or failed to read frame from 3ytUOoa1SBE_12_23.avi.
# Total frames extracted from 3ytUOoa1SBE_12_23.avi: 6
# Saved frames\186\186_0.jpg
# Saved frames\186\186_1.jpg
# Reached end of video or failed to read frame from 3zgEl-OLFKE_12_15.avi.
# Total frames extracted from 3zgEl-OLFKE_12_15.avi: 2
# Saved frames\187\187_0.jpg
# Saved frames\187\187_1.jpg
# Saved frames\187\187_2.jpg
# Saved frames\187\187_3.jpg
# Reached end of video or failed to read frame from 3zrVqwV29V8_69_76.avi.
# Total frames extracted from 3zrVqwV29V8_69_76.avi: 4
# Saved frames\188\188_0.jpg
# Saved frames\188\188_1.jpg
# Saved frames\188\188_2.jpg
# Saved frames\188\188_3.jpg
# Saved frames\188\188_4.jpg
# Reached end of video or failed to read frame from 4-1gpwkD7Hc_7_15.avi.
# Total frames extracted from 4-1gpwkD7Hc_7_15.avi: 5
# Saved frames\189\189_0.jpg
# Saved frames\189\189_1.jpg
# Saved frames\189\189_2.jpg
# Saved frames\189\189_3.jpg
# Saved frames\189\189_4.jpg
# Saved frames\189\189_5.jpg
# Reached end of video or failed to read frame from 45AGQSbodbU_5_15.avi.
# Total frames extracted from 45AGQSbodbU_5_15.avi: 6
# Saved frames\190\190_0.jpg
# Saved frames\190\190_1.jpg
# Saved frames\190\190_2.jpg
# Reached end of video or failed to read frame from 47D9-U8hn5I_11_16.avi.
# Total frames extracted from 47D9-U8hn5I_11_16.avi: 3
# Saved frames\191\191_0.jpg
# Saved frames\191\191_1.jpg
# Saved frames\191\191_2.jpg
# Saved frames\191\191_3.jpg
# Saved frames\191\191_4.jpg
# Reached end of video or failed to read frame from 4D1o4FC8YbA_207_216.avi.
# Total frames extracted from 4D1o4FC8YbA_207_216.avi: 5
# Saved frames\192\192_0.jpg
# Saved frames\192\192_1.jpg
# Saved frames\192\192_2.jpg
# Saved frames\192\192_3.jpg
# Saved frames\192\192_4.jpg
# Saved frames\192\192_5.jpg
# Reached end of video or failed to read frame from 4D1o4FC8YbA_29_39.avi.
# Total frames extracted from 4D1o4FC8YbA_29_39.avi: 6
# Saved frames\193\193_0.jpg
# Saved frames\193\193_1.jpg
# Saved frames\193\193_2.jpg
# Saved frames\193\193_3.jpg
# Saved frames\193\193_4.jpg
# Reached end of video or failed to read frame from 4Hhdr1IPOGs_1_10.avi.
# Total frames extracted from 4Hhdr1IPOGs_1_10.avi: 5
# Saved frames\194\194_0.jpg
# Saved frames\194\194_1.jpg
# Saved frames\194\194_2.jpg
# Saved frames\194\194_3.jpg
# Saved frames\194\194_4.jpg
# Reached end of video or failed to read frame from 4Hhdr1IPOGs_90_98.avi.
# Total frames extracted from 4Hhdr1IPOGs_90_98.avi: 5
# Saved frames\195\195_0.jpg
# Saved frames\195\195_1.jpg
# Saved frames\195\195_2.jpg
# Reached end of video or failed to read frame from 4JVpbYmqfcI_5_19.avi.
# Total frames extracted from 4JVpbYmqfcI_5_19.avi: 3
# Saved frames\196\196_0.jpg
# Saved frames\196\196_1.jpg
# Saved frames\196\196_2.jpg
# Saved frames\196\196_3.jpg
# Reached end of video or failed to read frame from 4MjTb5A68VA_111_118.avi.
# Total frames extracted from 4MjTb5A68VA_111_118.avi: 4
# Saved frames\197\197_0.jpg
# Saved frames\197\197_1.jpg
# Saved frames\197\197_2.jpg
# Saved frames\197\197_3.jpg
# Saved frames\197\197_4.jpg
# Reached end of video or failed to read frame from 4PayIIIOeIs_230_238.avi.
# Total frames extracted from 4PayIIIOeIs_230_238.avi: 5
# Saved frames\198\198_0.jpg
# Saved frames\198\198_1.jpg
# Saved frames\198\198_2.jpg
# Saved frames\198\198_3.jpg
# Reached end of video or failed to read frame from 4PcL6-mjRNk_11_18.avi.
# Total frames extracted from 4PcL6-mjRNk_11_18.avi: 4
# Saved frames\199\199_0.jpg
# Saved frames\199\199_1.jpg
# Saved frames\199\199_2.jpg
# Saved frames\199\199_3.jpg
# Saved frames\199\199_4.jpg
# Reached end of video or failed to read frame from 4PcL6-mjRNk_47_55.avi.
# Total frames extracted from 4PcL6-mjRNk_47_55.avi: 5
# Saved frames\200\200_0.jpg
# Saved frames\200\200_1.jpg
# Saved frames\200\200_2.jpg
# Saved frames\200\200_3.jpg
# Saved frames\200\200_4.jpg
# Saved frames\200\200_5.jpg
# Saved frames\200\200_6.jpg
# Reached end of video or failed to read frame from 4QYPZM01xFE_14_26.avi.
# Total frames extracted from 4QYPZM01xFE_14_26.avi: 7
